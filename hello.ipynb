# %%
from llama_stack_client import LlamaStackClient
from IPython.display import display
import os

# Set this to the model you want to test. Models supported are:
# - Llama3.1-8B-Instruct
# - llama-3.1-8b-instant
# - Llama-3-70B-Instruct
# - Llama3.3-70B-Instruct
model_id = "Llama3.1-8B-Instruct"

client = LlamaStackClient(
    base_url="http://localhost:5001",
)

response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "Hello, world client!"},
    ],
    # stream=True,
)

display(response)

# for chunk in response:
    # print(chunk)
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content='Hello! How can I assist you today?', role='assistant', stop_reason='end_of_turn', tool_calls=[]), logprobs=None)

# %%
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "Explain to me how ASGI in python works"},
    ],
    stream=True,
)

for chunk in response:
    print(chunk.event.delta, end='')
# Out:
# **ASGI Overview**
# ================
#
# ASGI (Asynchronous Server Gateway Interface) is a Python standard for building asynchronous web servers and applications. It provides a flexible and scalable way to handle HTTP requests and responses in an asynchronous manner.
#
# **Key Components**
# -----------------
#
# 1. **Server**: The ASGI server is responsible for receiving incoming HTTP requests and passing them to the application.
# 2. **Application**: The ASGI application is responsible for processing the incoming request and generating a response.
# 3. **Request**: The ASGI request object contains information about the incoming request, such as the method, path, headers, and body.
# 4. **Response**: The ASGI response object contains information about the response to be sent back to the client, such as the status code, headers, and body.
#
# **ASGI Protocol**
# ----------------
#
# The ASGI protocol defines a set of messages that are exchanged between the server and the application. The protocol consists of the following messages:
#
# 1. **ASGI_START**: Sent by the server to the application to indicate the start of a new request.
# 2. **ASGI_RECV**: Sent by the server to the application to receive data from the client.
# 3. **ASGI_SEND**: Sent by the application to the server to send data back to the client.
# 4. **ASGI_STOP**: Sent by the server to the application to indicate the end of a request.
#
# **ASGI Request/Response Cycle**
# ------------------------------
#
# Here's an overview of the ASGI request/response cycle:
#
# 1. **ASGI_START**: The server sends an `ASGI_START` message to the application to indicate the start of a new request.
# 2. **ASGI_RECV**: The server sends an `ASGI_RECV` message to the application to receive data from the client.
# 3. **Application Processing**: The application processes the incoming request and generates a response.
# 4. **ASGI_SEND**: The application sends an `ASGI_SEND` message to the server to send the response back to the client.
# 5. **ASGI_STOP**: The server sends an `ASGI_STOP` message to the application to indicate the end of the request.
#
# **Example ASGI Application**
# ---------------------------
#
# Here's a simple example of an ASGI application using the `aiohttp` library:
# ```python
# import aiohttp
# from aiohttp import web
#
# async def hello(request):
#     return web.Response(text="Hello, World!")
#
# app = web.Application()
# app.add_routes([web.get('/', hello)])
#
# web.run_app(app)
# ```
# In this example, the `hello` function is an ASGI application that responds to GET requests to the root URL (`/`) with a simple "Hello, World!" message.
#
# **ASGI Server**
# ----------------
#
# Here's an example of an ASGI server using the `uvicorn` library:
# ```python
# import uvicorn
#
# if __name__ == "__main__":
#     uvicorn.run("my_app:app", host="0.0.0.0", port=8000)
# ```
# In this example, the `uvicorn` library is used to run the ASGI application on port 8000.
#
# **Conclusion**
# ----------
#
# ASGI provides a flexible and scalable way to build asynchronous web servers and applications in Python. By understanding the ASGI protocol and request/response cycle, developers can build efficient and scalable web applications that take advantage of asynchronous programming.

# %%
from llama_models.datatypes import SamplingParams

response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "Explain to me how ASGI in python works"},
    ],
    stream=True,
    sampling_params=SamplingParams(
        temperature=0,
    ),
)

for chunk in response:
    print(chunk.event.delta, end='')
# Out:
# **ASGI Overview**
# ================
#
# ASGI (Asynchronous Server Gateway Interface) is a Python standard for building asynchronous web servers and applications. It provides a flexible and scalable way to handle HTTP requests and responses in an asynchronous manner.
#
# **Key Components**
# -----------------
#
# 1. **Server**: The ASGI server is responsible for receiving incoming HTTP requests and passing them to the application.
# 2. **Application**: The ASGI application is responsible for processing the incoming request and generating a response.
# 3. **Request**: The ASGI request object contains information about the incoming request, such as the method, path, headers, and body.
# 4. **Response**: The ASGI response object contains information about the response to be sent back to the client, such as the status code, headers, and body.
#
# **ASGI Protocol**
# ----------------
#
# The ASGI protocol defines a set of messages that are exchanged between the server and the application. The protocol consists of the following messages:
#
# 1. **ASGI_START**: Sent by the server to the application to indicate the start of a new request.
# 2. **ASGI_RECV**: Sent by the server to the application to receive data from the client.
# 3. **ASGI_SEND**: Sent by the application to the server to send data back to the client.
# 4. **ASGI_STOP**: Sent by the server to the application to indicate the end of a request.
#
# **ASGI Request/Response Cycle**
# ------------------------------
#
# Here's an overview of the ASGI request/response cycle:
#
# 1. **ASGI_START**: The server sends an `ASGI_START` message to the application to indicate the start of a new request.
# 2. **ASGI_RECV**: The server sends an `ASGI_RECV` message to the application to receive data from the client.
# 3. **Application Processing**: The application processes the incoming request and generates a response.
# 4. **ASGI_SEND**: The application sends an `ASGI_SEND` message to the server to send the response back to the client.
# 5. **ASGI_STOP**: The server sends an `ASGI_STOP` message to the application to indicate the end of the request.
#
# **Example ASGI Application**
# ---------------------------
#
# Here's a simple example of an ASGI application using the `aiohttp` library:
# ```python
# import aiohttp
# from aiohttp import web
#
# async def hello(request):
#     return web.Response(text="Hello, World!")
#
# app = web.Application()
# app.add_routes([web.get('/', hello)])
#
# web.run_app(app)
# ```
# In this example, the `hello` function is an ASGI application that responds to GET requests to the root URL (`/`) with a simple "Hello, World!" message.
#
# **ASGI Server**
# ----------------
#
# Here's an example of an ASGI server using the `uvicorn` library:
# ```python
# import uvicorn
#
# if __name__ == "__main__":
#     uvicorn.run("my_app:app", host="0.0.0.0", port=8000)
# ```
# In this example, the `uvicorn` library is used to run the ASGI application on port 8000.
#
# **Conclusion**
# ----------
#
# ASGI provides a flexible and scalable way to build asynchronous web servers and applications in Python. By understanding the ASGI protocol and request/response cycle, developers can build efficient and scalable web applications that take advantage of asynchronous programming.

# %%
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "Explain to me how ASGI in python works"},
    ],
    stream=True,
    sampling_params=SamplingParams(
        top_p=1
    ),
)

for chunk in response:
    print(chunk.event.delta, end='')
# Out:
# **ASGI Overview**
# ================
#
# ASGI (Asynchronous Server Gateway Interface) is a Python standard for building asynchronous web servers and applications. It provides a flexible and scalable way to handle HTTP requests and responses in an asynchronous manner.
#
# **Key Components**
# -----------------
#
# 1. **Server**: The ASGI server is responsible for receiving incoming HTTP requests and passing them to the application.
# 2. **Application**: The ASGI application is responsible for processing the incoming request and generating a response.
# 3. **Request**: The ASGI request object contains information about the incoming request, such as the method, path, headers, and body.
# 4. **Response**: The ASGI response object contains information about the response to be sent back to the client, such as the status code, headers, and body.
#
# **ASGI Protocol**
# ----------------
#
# The ASGI protocol defines a set of messages that are exchanged between the server and the application. The protocol consists of the following messages:
#
# 1. **ASGI_START**: Sent by the server to the application to indicate the start of a new request.
# 2. **ASGI_RECV**: Sent by the server to the application to receive data from the client.
# 3. **ASGI_SEND**: Sent by the application to the server to send data back to the client.
# 4. **ASGI_STOP**: Sent by the server to the application to indicate the end of a request.
#
# **ASGI Request/Response Cycle**
# ------------------------------
#
# Here's an overview of the ASGI request/response cycle:
#
# 1. **ASGI_START**: The server sends an `ASGI_START` message to the application to indicate the start of a new request.
# 2. **ASGI_RECV**: The server sends an `ASGI_RECV` message to the application to receive data from the client.
# 3. **Application Processing**: The application processes the incoming request and generates a response.
# 4. **ASGI_SEND**: The application sends an `ASGI_SEND` message to the server to send the response back to the client.
# 5. **ASGI_STOP**: The server sends an `ASGI_STOP` message to the application to indicate the end of the request.
#
# **Example ASGI Application**
# ---------------------------
#
# Here's a simple example of an ASGI application using the `aiohttp` library:
# ```python
# import aiohttp
# from aiohttp import web
#
# async def hello(request):
#     return web.Response(text="Hello, World!")
#
# app = web.Application()
# app.add_routes([web.get('/', hello)])
#
# web.run_app(app)
# ```
# In this example, the `hello` function is an ASGI application that responds to GET requests to the root URL (`/`) with a simple "Hello, World!" message.
#
# **ASGI Server**
# ----------------
#
# Here's an example of an ASGI server using the `uvicorn` library:
# ```python
# import uvicorn
#
# if __name__ == "__main__":
#     uvicorn.run("my_app:app", host="0.0.0.0", port=8000)
# ```
# In this example, the `uvicorn` library is used to run the ASGI application on port 8000.
#
# **Conclusion**
# ----------
#
# ASGI provides a flexible and scalable way to build asynchronous web servers and applications in Python. By understanding the ASGI protocol and request/response cycle, developers can build efficient and scalable web applications that take advantage of asynchronous programming.

# %%
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "Explain to me how ASGI in python works"},
    ],
    stream=True,
    sampling_params=SamplingParams(
        max_tokens=50
    ),
)

for chunk in response:
    print(chunk.event.delta, end='')
# Out:
# **ASGI Overview**
# ================
#
# ASGI (Asynchronous Server Gateway Interface) is a Python standard for building asynchronous web servers and applications. It provides a flexible and scalable way to handle HTTP requests and responses in an asynchronous manner.
#
# **Key Components**

# %%
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "Explain to me how ASGI in python works"},
    ],
    stream=True,
    sampling_params=SamplingParams(
        max_tokens=50
    ),
    logprobs={
        "top_k": 10,
    },
)

# for chunk in response:
#     print(chunk.event.delta, end='')
for chunk in response:
    print(chunk.event)
# Out:
# ChatCompletionResponseStreamChunkEvent(delta='', event_type='start', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='**', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='AS', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='GI', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' Overview', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='**\n', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='================', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='\n\n', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='AS', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='GI', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' (', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='As', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='ynchronous', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' Server', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' Gateway', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' Interface', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=')', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' is', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' a', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' Python', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' standard', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' for', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' building', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' asynchronous', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' web', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' servers', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' and', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' applications', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='.', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' It', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' provides', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' a', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' flexible', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' and', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' scalable', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' way', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' to', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' handle', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' HTTP', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' requests', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' and', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' responses', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' in', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' an', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' asynchronous', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' manner', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='.\n\n', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='**', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='Key', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta=' Components', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='**\n', event_type='progress', logprobs=None, stop_reason=None)
# ChatCompletionResponseStreamChunkEvent(delta='', event_type='complete', logprobs=None, stop_reason='out_of_tokens')

# %%
# Regular non-streamed tool call
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "When's the next flight from Adelaide to Sydney?"},
    ],
    # stream=True,
    tools=[
        {
            "tool_name": "get_flight_info",
            "description": "Get the flight information for a given origin and destination",
            "parameters": {
                "origin": {
                    "param_type": "string",
                    "description": "The origin airport code. E.g., AU",
                    "required": True,
                },
                "destination": {
                    "param_type": "string",
                    "description": "The destination airport code. E.g., 'LAX'",
                    "required": True,
                },
            }
        }
    ]
)

# for chunk in response:
#     print(chunk.event.delta, end='')
response
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content='', role='assistant', stop_reason='end_of_message', tool_calls=[ToolCall(arguments={'origin': 'ADL', 'destination': 'SYD'}, call_id='call_63be', tool_name='get_flight_info')]), logprobs=None)

# %%
# Regular non-streamed tool call
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "When's the next flight from Adelaide to Sydney?"},
    ],
    # stream=True,
    tools=[
        {
            "tool_name": "get_flight_info",
            "description": "Get the flight information for a given origin and destination",
            "parameters": {
                "origin": {
                    "param_type": "string",
                    "description": "The origin airport code. E.g., AU",
                    "required": True,
                },
                "destination": {
                    "param_type": "string",
                    "description": "The destination airport code. E.g., 'LAX'",
                    "required": True,
                },
            }
        }
    ]
)

# for chunk in response:
#     print(chunk.event.delta, end='')
response
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content='', role='assistant', stop_reason='end_of_message', tool_calls=[ToolCall(arguments={'origin': 'ADL', 'destination': 'SYD'}, call_id='call_byhp', tool_name='get_flight_info')]), logprobs=None)

# %%
# Streamed tool call
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "When's the next flight from Adelaide to Sydney? Also find a hotel in the Sydney area for 3 nights starting on the 1st of January 2024. Should be smoking friendly."},
    ],
    stream=True,
    tools=[
        {
            "tool_name": "get_flight_info",
            "description": "Get the flight information for a given origin and destination",
            "parameters": {
                "origin": {
                    "param_type": "string",
                    "description": "The origin airport code. E.g., AU",
                    "required": True,
                },
                "destination": {
                    "param_type": "string",
                    "description": "The destination airport code. E.g., 'LAX'",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "get_hotel_info",
            "description": "Get the hotel information for a given destination",
            "parameters": {
                "post_code": {
                    "param_type": "string",
                    "description": "The post code of the area to search for hotels. E.g., '2000'",
                    "required": True,
                },
                "num_nights": {
                    "param_type": "integer",
                    "description": "The number of nights to stay. E.g., 3",
                    "required": True,
                },
                "date_from": {
                    "param_type": "string",
                    "description": "The date to start the stay formatted as YYYY-MM-DD. E.g., '2024-01-01'",
                    "required": True,
                },
                "smoking_friendly": {
                    "param_type": "boolean",
                    "description": "Whether the hotel is smoking friendly. E.g., True",
                    "required": False,
                },
            }
        },
    ]
)

for chunk in response:
    print(chunk.event.delta)
# Out:
# ChatCompletionResponseStreamChunkEventDeltaToolCallDelta(content=ToolCall(arguments={'origin': 'ADL', 'destination': 'SYD'}, call_id='call_y2g6', tool_name='get_flight_info'), parse_status='success')
# ChatCompletionResponseStreamChunkEventDeltaToolCallDelta(content=ToolCall(arguments={'date_from': '2024-01-01', 'num_nights': 3.0, 'post_code': '2000', 'smoking_friendly': True}, call_id='call_zebm', tool_name='get_hotel_info'), parse_status='success')

# %%
# Multiple tool calls in one chat completion
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": "When's the next flight from Adelaide to Sydney? Also find a hotel in the Sydney area for 3 nights starting on the 1st of January 2024. Should be smoking friendly."},
    ],
    # stream=True,
    tools=[
        {
            "tool_name": "get_flight_info",
            "description": "Get the flight information for a given origin and destination",
            "parameters": {
                "origin": {
                    "param_type": "string",
                    "description": "The origin airport code. E.g., AU",
                    "required": True,
                },
                "destination": {
                    "param_type": "string",
                    "description": "The destination airport code. E.g., 'LAX'",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "get_hotel_info",
            "description": "Get the hotel information for a given destination",
            "parameters": {
                "post_code": {
                    "param_type": "string",
                    "description": "The post code of the area to search for hotels. E.g., '2000'",
                    "required": True,
                },
                "num_nights": {
                    "param_type": "integer",
                    "description": "The number of nights to stay. E.g., 3",
                    "required": True,
                },
                "date_from": {
                    "param_type": "string",
                    "description": "The date to start the stay formatted as YYYY-MM-DD. E.g., '2024-01-01'",
                    "required": True,
                },
                "smoking_friendly": {
                    "param_type": "boolean",
                    "description": "Whether the hotel is smoking friendly. E.g., True",
                    "required": False,
                },
            }
        },
    ]
)

print(response)

for tool_call in response.completion_message.tool_calls:
    print(tool_call)
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content='', role='assistant', stop_reason='end_of_message', tool_calls=[ToolCall(arguments={'origin': 'ADL', 'destination': 'SYD'}, call_id='call_c8eq', tool_name='get_flight_info'), ToolCall(arguments={'date_from': '2024-01-01', 'num_nights': 3.0, 'post_code': '2000', 'smoking_friendly': True}, call_id='call_zz9x', tool_name='get_hotel_info')]), logprobs=None)
# ToolCall(arguments={'origin': 'ADL', 'destination': 'SYD'}, call_id='call_c8eq', tool_name='get_flight_info')
# ToolCall(arguments={'date_from': '2024-01-01', 'num_nights': 3.0, 'post_code': '2000', 'smoking_friendly': True}, call_id='call_zz9x', tool_name='get_hotel_info')

# %%
# Test for floats
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            Multiply 2.5 and 3.5
         """},
    ],
    # stream=True,
    tools=[
        {
            "tool_name": "multiply",
            "description": "Multiply two numbers",
            "parameters": {
                "a": {
                    "param_type": "float",
                    "description": "The first number to multiply. E.g., 2.5",
                    "required": True,
                },
                "b": {
                    "param_type": "float",
                    "description": "The second number to multiply. E.g., 3.5",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "get_hotel_info",
            "description": "Get the hotel information for a given destination",
            "parameters": {
                "address": {
                    "param_type": "object",
                    "description": "The address of the hotel. E.g., {'street_address': '123 Main St', 'city': 'Sydney', 'state': 'NSW', 'post_code': '2000'}",
                    "properties": {
                        "street_address": {
                            "param_type": "string",
                            "description": "The street address of the hotel. E.g., '123 Main St'",
                            "required": True,
                        },
                        "city": {
                            "param_type": "string",
                            "description": "The city of the hotel. E.g., 'Sydney'",
                            "required": True,
                        },
                        "state": {
                            "param_type": "string",
                            "description": "The state of the hotel. E.g., 'NSW'",
                            "required": True,
                        },
                        "post_code": {
                            "param_type": "string",
                            "description": "The post code of the hotel. E.g., '2000'",
                            "required": True,
                        },
                    },
                    "required": True,
                },
                "num_nights": {
                    "param_type": "integer",
                    "description": "The number of nights to stay. E.g., 3",
                    "required": True,
                },
                "date_from": {
                    "param_type": "string",
                    "description": "The date to start the stay formatted as YYYY-MM-DD. E.g., '2024-01-01'",
                    "required": True,
                },
                "smoking_friendly": {
                    "param_type": "boolean",
                    "description": "Whether the hotel is smoking friendly. E.g., True",
                    "required": False,
                },
            }
        },
    ]
)

print(response)

for tool_call in response.completion_message.tool_calls:
    print(tool_call)
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content='', role='assistant', stop_reason='end_of_message', tool_calls=[ToolCall(arguments={'a': 2.5, 'b': 3.5}, call_id='call_52g6', tool_name='multiply')]), logprobs=None)
# ToolCall(arguments={'a': 2.5, 'b': 3.5}, call_id='call_52g6', tool_name='multiply')

# %%
# Test tool choice
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            Explain to me how ASGI in python works
         """},
    ],
    # stream=True,
    tool_choice="required",
    tools=[
        {
            "tool_name": "multiply",
            "description": "Multiply two numbers",
            "parameters": {
                "a": {
                    "param_type": "float",
                    "description": "The first number to multiply. E.g., 2.5",
                    "required": True,
                },
                "b": {
                    "param_type": "float",
                    "description": "The second number to multiply. E.g., 3.5",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "get_hotel_info",
            "description": "Get the hotel information for a given destination",
            "parameters": {
                "address": {
                    "param_type": "object",
                    "description": "The address of the hotel. E.g., {'street_address': '123 Main St', 'city': 'Sydney', 'state': 'NSW', 'post_code': '2000'}",
                    "properties": {
                        "street_address": {
                            "param_type": "string",
                            "description": "The street address of the hotel. E.g., '123 Main St'",
                            "required": True,
                        },
                        "city": {
                            "param_type": "string",
                            "description": "The city of the hotel. E.g., 'Sydney'",
                            "required": True,
                        },
                        "state": {
                            "param_type": "string",
                            "description": "The state of the hotel. E.g., 'NSW'",
                            "required": True,
                        },
                        "post_code": {
                            "param_type": "string",
                            "description": "The post code of the hotel. E.g., '2000'",
                            "required": True,
                        },
                    },
                    "required": True,
                },
                "num_nights": {
                    "param_type": "integer",
                    "description": "The number of nights to stay. E.g., 3",
                    "required": True,
                },
                "date_from": {
                    "param_type": "string",
                    "description": "The date to start the stay formatted as YYYY-MM-DD. E.g., '2024-01-01'",
                    "required": True,
                },
                "smoking_friendly": {
                    "param_type": "boolean",
                    "description": "Whether the hotel is smoking friendly. E.g., True",
                    "required": False,
                },
            }
        },
    ]
)

print(response)

for tool_call in response.completion_message.tool_calls:
    print(tool_call)
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content='', role='assistant', stop_reason='end_of_message', tool_calls=[ToolCall(arguments={'query': 'ASGI in python explanation'}, call_id='call_321w', tool_name='brave_search'), ToolCall(arguments={'query': 'ASGI python architecture'}, call_id='call_gr3m', tool_name='brave_search'), ToolCall(arguments={'query': 'ASGI python example'}, call_id='call_xxhg', tool_name='brave_search')]), logprobs=None)
# ToolCall(arguments={'query': 'ASGI in python explanation'}, call_id='call_321w', tool_name='brave_search')
# ToolCall(arguments={'query': 'ASGI python architecture'}, call_id='call_gr3m', tool_name='brave_search')
# ToolCall(arguments={'query': 'ASGI python example'}, call_id='call_xxhg', tool_name='brave_search')

# %%
# Test tool choice
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            Explain to me how ASGI in python works
         """},
    ],
    # stream=True,
    tool_choice="auto",
    tools=[
        {
            "tool_name": "multiply",
            "description": "Multiply two numbers",
            "parameters": {
                "a": {
                    "param_type": "float",
                    "description": "The first number to multiply. E.g., 2.5",
                    "required": True,
                },
                "b": {
                    "param_type": "float",
                    "description": "The second number to multiply. E.g., 3.5",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "get_hotel_info",
            "description": "Get the hotel information for a given destination",
            "parameters": {
                "address": {
                    "param_type": "object",
                    "description": "The address of the hotel. E.g., {'street_address': '123 Main St', 'city': 'Sydney', 'state': 'NSW', 'post_code': '2000'}",
                    "properties": {
                        "street_address": {
                            "param_type": "string",
                            "description": "The street address of the hotel. E.g., '123 Main St'",
                            "required": True,
                        },
                        "city": {
                            "param_type": "string",
                            "description": "The city of the hotel. E.g., 'Sydney'",
                            "required": True,
                        },
                        "state": {
                            "param_type": "string",
                            "description": "The state of the hotel. E.g., 'NSW'",
                            "required": True,
                        },
                        "post_code": {
                            "param_type": "string",
                            "description": "The post code of the hotel. E.g., '2000'",
                            "required": True,
                        },
                    },
                    "required": True,
                },
                "num_nights": {
                    "param_type": "integer",
                    "description": "The number of nights to stay. E.g., 3",
                    "required": True,
                },
                "date_from": {
                    "param_type": "string",
                    "description": "The date to start the stay formatted as YYYY-MM-DD. E.g., '2024-01-01'",
                    "required": True,
                },
                "smoking_friendly": {
                    "param_type": "boolean",
                    "description": "Whether the hotel is smoking friendly. E.g., True",
                    "required": False,
                },
            }
        },
    ]
)

print(response)

for tool_call in response.completion_message.tool_calls:
    print(tool_call)
# Out:
# ChatCompletionResponse(completion_message=CompletionMessage(content="ASGI (Asynchronous Server Gateway Interface) is a standard for building asynchronous web servers and applications in Python. It was created as a replacement for the older WSGI (Web Server Gateway Interface) standard, which was designed for synchronous web development.\n\nHere's a high-level overview of how ASGI works:\n\n1. **Request/Response Cycle**: When a client (e.g., a web browser) sends a request to a server, the server processes the request and sends a response back to the client. This is the basic request/response cycle.\n\n2. **ASGI Application**: An ASGI application is a Python callable that handles incoming requests and returns responses. It's the core of an ASGI server.\n\n3. **ASGI Server**: An ASGI server is responsible for receiving incoming requests, passing them to the ASGI application, and sending the response back to the client. ASGI servers can be built using various frameworks, such as uvicorn, hypercorn, or starlette.\n\n4. **ASGI Protocol**: The ASGI protocol defines how the server and application communicate with each other. It's based on a simple request/response model, where the server sends a message to the application, and the application sends a response back to the server.\n\n5. **ASGI Messages**: ASGI messages are the basic units of communication between the server and application. There are three types of messages:\n\t* **ASGI Receive Message**: Sent from the server to the application, indicating that a request is available.\n\t* **ASGI Send Message**: Sent from the application to the server, indicating that a response is ready.\n\t* **ASGI Lifecycle Message**: Sent from the server to the application, indicating that the server is shutting down.\n\n6. **ASGI Event Loop**: The ASGI event loop is responsible for managing the asynchronous execution of the ASGI application. It's typically implemented using a library like asyncio.\n\nHere's a simplified example of how an ASGI application might work:\n\n```python\nimport asyncio\n\nasync def my_app(scope, receive, send):\n    # Receive the request message\n    await receive()\n\n    # Send a response message\n    await send({\n        'type': 'http.response.start',\n        'status': 200,\n        'headers': [\n            [b'content-type', b'text/plain'],\n        ],\n    })\n\n    # Send the response body\n    await send({\n        'type': 'http.response.body',\n        'body': b'Hello, World!',\n    })\n\n# Create an ASGI server\nasync def main():\n    # Create an ASGI application\n    app = my_app\n\n    # Run the ASGI server\n    await app({'type': 'http.request', 'method': 'GET', 'path': '/'})\n\n# Run the main function\nasyncio.run(main())\n```\n\nIn this example, the `my_app` function is an ASGI application that handles incoming requests and sends responses back to the client. The `main` function creates an ASGI server and runs the `my_app` application.\n\nOverall, ASGI provides a flexible and efficient way to build asynchronous web servers and applications in Python.", role='assistant', stop_reason='end_of_turn', tool_calls=[]), logprobs=None)

# %%
# 10 thousand character tool call
# We hit the max output token limit for 3.1-8b-instruct
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            Count the number of characters in the following text:
            Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non. Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non. Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. 
         """},
    ],
    stream=True,
    tool_choice="required",
    tools=[
        {
            "tool_name": "count_characters",
            "description": "Count the number of characters in a text",
            "parameters": {
                "text": {
                    "param_type": "string",
                    "description": "The text to count the characters of",
                    "required": True,
                },
            }
        }
    ]
)

for chunk in response:
    print(chunk)
# Out:
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta='', event_type='complete', logprobs=None, stop_reason='out_of_tokens'))

# %%
# 10 thousand character tool call
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            Count the number of characters in the following text:
            Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non. Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non.Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. In nec lorem metus. Nunc molestie mollis enim, vitae volutpat elit blandit non. Donec eu lorem eget quam accumsan iaculis. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. per conubia nostra, per inceptos himenaeos. Aenean felis tortor, tincidunt eu purus at, lacinia mollis mi. Aliquam lacinia molestie augue ac vestibulum. Duis ante lacus, vulputate a sollicitudin in, consectetur fermentum augue. Maecenas eget risus a dolor mattis feugiat. Integer accumsan tempor elit vel imperdiet. Donec et dignissim velit. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Mauris dictum, nibh id varius accumsan, massa risus aliquam diam, at pulvinar risus risus sit amet erat. 
         """},
    ],
    stream=True,
    tool_choice="required",
    tools=[
        {
            "tool_name": "count_characters",
            "description": "Count the number of characters in a text",
            "parameters": {
                "text": {
                    "param_type": "string",
                    "description": "The text to count the characters of",
                    "required": True,
                },
            }
        }
    ]
)

for chunk in response:
    print(chunk)
# Out:
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta='', event_type='complete', logprobs=None, stop_reason='out_of_tokens'))

# %%
# Test multiple tool calls streaming
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            What is the logarithm of 10? What is 3.52 + 4.89? What is 3.52 * 4.89?
         """},
    ],
    stream=True,
    tool_choice="required",
    tools=[
        {
            "tool_name": "multiply",
            "description": "Multiply two numbers",
            "parameters": {
                "a": {
                    "param_type": "float",
                    "description": "The first number to multiply. E.g., 2.5",
                    "required": True,
                },
                "b": {
                    "param_type": "float",
                    "description": "The second number to multiply. E.g., 3.5",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "add",
            "description": "Add two numbers",
            "parameters": {
                "a": {
                    "param_type": "float",
                    "description": "The first number to add. E.g., 2.5",
                    "required": True,
                },
                "b": {
                    "param_type": "float",
                    "description": "The second number to add. E.g., 3.5",
                    "required": True,
                },
            }
        },
        {
            "tool_name": "log",
            "description": "Calculate the logarithm of a number",
            "parameters": {
                "message": {
                    "param_type": "float",
                    "description": "The number to calculate the logarithm of. E.g., 10, 200, 5.5 etc.",
                    "required": True,
                },
            }
        }
    ]
)

for chunk in response:
    print(chunk)
# Out:
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta='', event_type='start', logprobs=None, stop_reason=None))
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta=ChatCompletionResponseStreamChunkEventDeltaToolCallDelta(content=ToolCall(arguments={'message': 10.0}, call_id='call_f5t5', tool_name='calculate_log'), parse_status='success'), event_type='progress', logprobs=None, stop_reason=None))
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta=ChatCompletionResponseStreamChunkEventDeltaToolCallDelta(content=ToolCall(arguments={'a': 3.52, 'b': 4.89}, call_id='call_8wnf', tool_name='add'), parse_status='success'), event_type='progress', logprobs=None, stop_reason=None))
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta=ChatCompletionResponseStreamChunkEventDeltaToolCallDelta(content=ToolCall(arguments={'a': 3.52, 'b': 4.89}, call_id='call_kz4v', tool_name='multiply'), parse_status='success'), event_type='progress', logprobs=None, stop_reason=None))
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta='', event_type='complete', logprobs=None, stop_reason='end_of_message'))

# %%
# No parameter tool call
response = client.inference.chat_completion(
    model_id=model_id,
    messages=[
        {"role": "user", "content": """
            Trigger a build
         """},
    ],
    stream=True,
    tool_choice="required",
    tools=[
        {
            "tool_name": "trigger_build",
            "description": "Trigger a build",
            "parameters": {
            }
        }
    ]
)

for chunk in response:
    print(chunk)
# Out:
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta='', event_type='start', logprobs=None, stop_reason=None))
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta=ChatCompletionResponseStreamChunkEventDeltaToolCallDelta(content=ToolCall(arguments={}, call_id='call_ebmz', tool_name='trigger_build'), parse_status='success'), event_type='progress', logprobs=None, stop_reason=None))
# ChatCompletionResponseStreamChunk(event=ChatCompletionResponseStreamChunkEvent(delta='', event_type='complete', logprobs=None, stop_reason='end_of_message'))
